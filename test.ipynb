# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('dataset/xt_seq_msod_x/MSOD/train/images/0001/00001.tif', -1)
img2 = cv2.imread('dataset/xt_seq_msod_x/MSOD/train/images/0001/00002.tif', -1)
sub = img2 - img1

# %%
plt.imshow(sub)
