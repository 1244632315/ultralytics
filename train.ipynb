# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# WARNING ⚠️ Multiple Ultralytics installations detected. The `yolo` command uses: /home/chris/miniconda3/envs/yolo/lib/python3.9/site-packages/ultralytics, but current session imports from: /home/chris/ultralytics/ultralytics. This may cause version conflicts. Install your local copy in editable mode with 'pip install -e /home/chris/ultralytics' to avoid issues. See https://docs.ultralytics.com/quickstart/
# Ultralytics 8.4.14 🚀 Python-3.9.25 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24564MiB)
# Setup complete ✅ (24 CPUs, 31.2 GB RAM, 629.6/1006.9 GB disk)

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=runs/detect/yolo11n_new_dataset/weights/best.pt source=test_img.png imgsz=1024
# Out:
# Ultralytics 8.4.14 🚀 Python-3.9.25 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24564MiB)
# YOLO11n summary (fused): 101 layers, 2,582,059 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /home/chris/ultralytics/test_img.png: 1024x1024 2 lines, 53.4ms
# Speed: 1.1ms preprocess, 53.4ms inference, 11.7ms postprocess per image at shape (1, 1, 1024, 1024)
# Results saved to /home/chris/ultralytics/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
